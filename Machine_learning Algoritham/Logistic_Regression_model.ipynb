# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('bank-additional-full.csv' , sep= ';')

# %%
data.head()
# Out:
#     age        job  marital    education  default housing loan    contact  \
# 0  56.0  housemaid  married     basic.4y       no      no   no  telephone
# 1  57.0   services  married  high.school  unknown      no   no  telephone
# 2  37.0   services  married  high.school       no     yes   no  telephone
# 3  40.0     admin.  married     basic.6y       no      no   no  telephone
# 4  56.0   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 1   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 2   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 3   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 4   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
#
# ...

# %%
data.shape
# Out:
# (41199, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41199 entries, 0 to 41198
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41195 non-null  float64
#  1   job             41194 non-null  object
#  2   marital         41194 non-null  object
#  3   education       41194 non-null  object
#  4   default         41195 non-null  object
#  5   housing         41196 non-null  object
#  6   loan            41195 non-null  object
#  7   contact         41195 non-null  object
#  8   month           41196 non-null  object
#  9   day_of_week     41196 non-null  object
#  10  duration        41196 non-null  float64
#  11  campaign        41196 non-null  float64
#  12  pdays           41196 non-null  float64
#  13  previous        41196 non-null  float64
#  14  poutcome        41194 non-null  object
#  15  emp.var.rate    41196 non-null  float64
#  16  cons.price.idx  41195 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# age               4
# job               5
# marital           5
# education         5
# default           4
# housing           3
# loan              4
# contact           4
# month             3
# day_of_week       3
# duration          3
# campaign          3
# pdays             3
# previous          3
# poutcome          5
# emp.var.rate      3
# cons.price.idx    4
# cons.conf.idx     3
# euribor3m         3
# nr.employed       3
# y                 3
# dtype: int64

# %%
# since there are null values present in data set but it is ver less so i am dropping the null-values

# %%
data = data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41190 entries, 0 to 41194
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41190 non-null  float64
#  1   job             41190 non-null  object
#  2   marital         41190 non-null  object
#  3   education       41190 non-null  object
#  4   default         41190 non-null  object
#  5   housing         41190 non-null  object
#  6   loan            41190 non-null  object
#  7   contact         41190 non-null  object
#  8   month           41190 non-null  object
#  9   day_of_week     41190 non-null  object
#  10  duration        41190 non-null  float64
#  11  campaign        41190 non-null  float64
#  12  pdays           41190 non-null  float64
#  13  previous        41190 non-null  float64
#  14  poutcome        41190 non-null  object
#  15  emp.var.rate    41190 non-null  float64
#  16  cons.price.idx  41190 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
data= data.drop_duplicates()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41177 entries, 0 to 41193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41177 non-null  float64
#  1   job             41177 non-null  object
#  2   marital         41177 non-null  object
#  3   education       41177 non-null  object
#  4   default         41177 non-null  object
#  5   housing         41177 non-null  object
#  6   loan            41177 non-null  object
#  7   contact         41177 non-null  object
#  8   month           41177 non-null  object
#  9   day_of_week     41177 non-null  object
#  10  duration        41177 non-null  float64
#  11  campaign        41177 non-null  float64
#  12  pdays           41177 non-null  float64
#  13  previous        41177 non-null  float64
#  14  poutcome        41177 non-null  object
#  15  emp.var.rate    41177 non-null  float64
#  16  cons.price.idx  41177 non-null  float64
# ...

# %%
col_list = list(data.columns)

# %%
for col_names in col_list:
  if data[col_names].dtypes == 'float64':
    sns.boxplot(data[col_names])
    plt.xlabel(col_names)
    plt.ylabel('Count')
    plt.show()

# %%
# let us remove outliers first

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3-Q1
print(IQR)
# Out:
# age                15.000
# duration          217.000
# campaign            2.000
# pdays               0.000
# previous            0.000
# emp.var.rate        3.200
# cons.price.idx      0.919
# cons.conf.idx       6.300
# euribor3m           3.617
# nr.employed       129.000
# dtype: float64

# %%
data = data[~((data < (Q1 - 1.5 * IQR)) |(data > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
for col_names in col_list:
  if data[col_names].dtypes == 'float64':
    sns.boxplot(data[col_names])
    plt.xlabel(col_names)
    plt.ylabel('Count')
    plt.show()

# %%
# so outliers are removed

# %%
data.shape
# Out:
# (30349, 21)

# %%
data.head()
# Out:
#     age        job  marital    education  default housing loan    contact  \
# 0  56.0  housemaid  married     basic.4y       no      no   no  telephone
# 1  57.0   services  married  high.school  unknown      no   no  telephone
# 2  37.0   services  married  high.school       no     yes   no  telephone
# 3  40.0     admin.  married     basic.6y       no      no   no  telephone
# 4  56.0   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 1   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 2   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 3   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 4   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
#
# ...

# %%
# since age column has lot of diffrent values so let us create a bin to store them.

# %%
data.age.max()
# Out:
# 69.0

# %%
data.age.min()
# Out:
# 18.0

# %%
bins = [10,25,40,55,70]

# %%
data['age']= pd.cut(data['age'],bins)
data['age'] = data.age.astype(str)

# %%
data.head()
# Out:
#         age        job  marital    education  default housing loan    contact  \
# 0  (55, 70]  housemaid  married     basic.4y       no      no   no  telephone
# 1  (55, 70]   services  married  high.school  unknown      no   no  telephone
# 2  (25, 40]   services  married  high.school       no     yes   no  telephone
# 3  (25, 40]     admin.  married     basic.6y       no      no   no  telephone
# 4  (55, 70]   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 1   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 2   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 3   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 4   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE = LabelEncoder()

# %%
col_list = data.columns

# %%
for col_names in col_list:
  data[col_names] = LE.fit_transform(data[col_names])

# %%
data.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0    3    3        1          0        0        0     0        1      6
# 1    3    7        1          3        1        0     0        1      6
# 2    1    7        1          3        0        2     0        1      6
# 3    1    0        1          1        0        0     0        1      6
# 4    3    7        1          3        0        0     2        1      6
#
#    day_of_week  ...  campaign  pdays  previous  poutcome  emp.var.rate  \
# 0            1  ...         0      0         0         0             8
# 1            1  ...         0      0         0         0             8
# 2            1  ...         0      0         0         0             8
# 3            1  ...         0      0         0         0             8
# 4            1  ...         0      0         0         0             8
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30349 entries, 0 to 41186
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30349 non-null  int64
#  1   job             30349 non-null  int64
#  2   marital         30349 non-null  int64
#  3   education       30349 non-null  int64
#  4   default         30349 non-null  int64
#  5   housing         30349 non-null  int64
#  6   loan            30349 non-null  int64
#  7   contact         30349 non-null  int64
#  8   month           30349 non-null  int64
#  9   day_of_week     30349 non-null  int64
#  10  duration        30349 non-null  int64
#  11  campaign        30349 non-null  int64
#  12  pdays           30349 non-null  int64
#  13  previous        30349 non-null  int64
#  14  poutcome        30349 non-null  int64
#  15  emp.var.rate    30349 non-null  int64
#  16  cons.price.idx  30349 non-null  int64
# ...

# %%
# let check for multi colinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
col_list =[]
for col_names in data.columns:
  if data[col_names].dtypes =='int64' and col_names != 'y':
    col_list.append(col_names)

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
col_list
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed']

# %%
X = data[col_list]

# %%
vif = pd.DataFrame()
vif['features'] = X.columns
vif['VIF_Score'] = [variance_inflation_factor(X.values , i) for i in range(len(X.columns))]
vif
# Out:
#           features   VIF_Score
# 0              age    6.157636
# 1              job    2.086953
# 2          marital    5.091451
# 3        education    4.340365
# 4          default    1.424186
# 5          housing    2.165370
# 6             loan    1.207204
# 7          contact    4.276852
# 8            month    5.070633
# 9      day_of_week    3.068563
# 10        duration    3.154679
# 11        campaign    1.703106
# 12           pdays         NaN
# 13        previous         NaN
# 14        poutcome         NaN
# 15    emp.var.rate  101.107243
# 16  cons.price.idx   44.077784
# 17   cons.conf.idx    7.039294
# 18       euribor3m  177.052804
# 19     nr.employed  176.201682

# %%
data.drop('euribor3m', axis = 1 , inplace = True)

# %%
col_list = []
for x in data.columns:
  if data[x].dtypes =='int64' and x != 'y':
    col_list.append(x)
col_list
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'nr.employed']

# %%
X = data[col_list]

# %%
vif = pd.DataFrame()
vif['features'] = X.columns
vif['VIF_Score'] = [variance_inflation_factor(X.values , i) for i in range(len(X.columns))]
vif
# Out:
#           features   VIF_Score
# 0              age    6.103099
# 1              job    2.084389
# 2          marital    5.027246
# 3        education    4.322251
# 4          default    1.422297
# 5          housing    2.157253
# 6             loan    1.206837
# 7          contact    4.275564
# 8            month    4.801284
# 9      day_of_week    3.059046
# 10        duration    3.138137
# 11        campaign    1.702358
# 12           pdays         NaN
# 13        previous         NaN
# 14        poutcome         NaN
# 15    emp.var.rate  101.107236
# 16  cons.price.idx   41.565993
# 17   cons.conf.idx    6.912364
# 18     nr.employed   72.989836

# %%
data.drop('emp.var.rate',axis = 1,inplace = True)

# %%
col_list=[]
for col in data.columns:
  if data[col].dtypes =='int64' and col !='y':
    col_list.append(col)
col_list
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'nr.employed']

# %%
X = data[col_list]

# %%
vif = pd.DataFrame()
vif['features'] = X.columns
vif['VIF_Score'] = [variance_inflation_factor(X.values , i) for i in range(len(X.columns))]
vif
# Out:
#           features  VIF_Score
# 0              age   5.610636
# 1              job   2.075161
# 2          marital   4.563494
# 3        education   4.212406
# 4          default   1.422062
# 5          housing   2.132136
# 6             loan   1.204940
# 7          contact   4.049909
# 8            month   4.577520
# 9      day_of_week   3.036799
# 10        duration   3.024320
# 11        campaign   1.693464
# 12           pdays        NaN
# 13        previous        NaN
# 14        poutcome        NaN
# 15  cons.price.idx  20.534042
# 16   cons.conf.idx   5.018618
# 17     nr.employed  21.608520

# %%
data.drop('nr.employed',axis = 1 ,inplace = True)

# %%
col_list=[]
for col in data.columns:
  if data[col].dtypes =='int64' and col !='y':
    col_list.append(col)
col_list
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'cons.price.idx',
#  'cons.conf.idx']

# %%
X = data[col_list]

# %%
vif = pd.DataFrame()
vif['features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values , i ) for i in range(len(X.columns))]
vif
# Out:
#           features        VIF
# 0              age   5.325638
# 1              job   2.069721
# 2          marital   4.453645
# 3        education   4.129539
# 4          default   1.415154
# 5          housing   2.116354
# 6             loan   1.203649
# 7          contact   3.462909
# 8            month   4.574765
# 9      day_of_week   2.983648
# 10        duration   3.019663
# 11        campaign   1.676132
# 12           pdays        NaN
# 13        previous        NaN
# 14        poutcome        NaN
# 15  cons.price.idx  10.801032
# 16   cons.conf.idx   4.807204

# %%
data.drop('cons.price.idx',axis = 1 ,inplace = True)

# %%
col_list =[]
for x in data.columns:
  if data[x].dtypes =='int64' and x != 'y':
    col_list.append(x)

col_list
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'cons.conf.idx']

# %%
X = data[col_list]

# %%
vif=pd.DataFrame()
vif['features'] = X.columns
vif['VIF_Score'] = [variance_inflation_factor (X.values , i) for i in range(len(X.columns))]
vif
# Out:
#          features  VIF_Score
# 0             age   4.767611
# 1             job   2.056816
# 2         marital   4.138077
# 3       education   4.010450
# 4         default   1.390789
# 5         housing   2.103156
# 6            loan   1.200866
# 7         contact   2.310416
# 8           month   4.573487
# 9     day_of_week   2.900680
# 10       duration   2.935907
# 11       campaign   1.642451
# 12          pdays        NaN
# 13       previous        NaN
# 14       poutcome        NaN
# 15  cons.conf.idx   4.807203

# %%
data.drop(['pdays','previous','poutcome'],axis = 1 , inplace =True)

# %%
# lets build a model now

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign',
#        'cons.conf.idx', 'y'],
#       dtype='object')

# %%
data
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0        3    3        1          0        0        0     0        1      6
# 1        3    7        1          3        1        0     0        1      6
# 2        1    7        1          3        0        2     0        1      6
# 3        1    0        1          1        0        0     0        1      6
# 4        3    7        1          3        0        0     2        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41180    1    0        1          6        0        0     0        0      7
# 41181    1    0        1          6        0        2     0        0      7
# 41184    2    1        1          5        0        0     0        0      7
# 41185    3    5        1          6        0        2     0        0      7
# 41186    2    9        1          5        0        0     0        0      7
#
#        day_of_week  duration  campaign  cons.conf.idx  y
# ...

# %%
X = data.drop('y',axis = 1)

# %%
Y = data['y']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,train_size = 0.70 , random_state = 1)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (21244, 13)
# (9105, 13)
# (21244,)
# (9105,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
Lr =LogisticRegression()

# %%
Lr.fit(x_train , y_train)
# Out:
# LogisticRegression()

# %%
pred = Lr.predict(x_test)

# %%
pd.DataFrame(Lr.predict_proba(x_test))
# Out:
#              0         1
# 0     0.955266  0.044734
# 1     0.868042  0.131958
# 2     0.949443  0.050557
# 3     0.939400  0.060600
# 4     0.461325  0.538675
# ...        ...       ...
# 9100  0.913782  0.086218
# 9101  0.990425  0.009575
# 9102  0.930968  0.069032
# 9103  0.916006  0.083994
# 9104  0.996959  0.003041
#
# [9105 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
confusion_matrix(pred,y_test)
# Out:
# array([[8603,  458],
#        [  25,   19]])

# %%
accuracy_score(y_test,pred)
# Out:
# 0.9469522240527183
